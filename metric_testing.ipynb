# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = [25, 50, 100, 250, 500, 1000, 2000]
metrics = [1.3976613342495223, 1.3068694709792172, 1.164507562690769, 0.8871369502540237, 0.7334648299889387, 0.5989195297684063, 0.49449702718582683]
plt.plot(N, metrics)

# run for N = 5000 and check convergence, look for a practical value of N for optimization of hyperparameters
